# %%
import pandas as pd 
import geopandas as gpd
year = [2012]
months = [6,7]
for y in year:
    for x in months:
        if x < 10:
            #for administrative level 1
            adm01shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/NTLstats2012_adm01_mean.shp'.format(y,x))
            adm01shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/NTLstats2012_adm01_median.shp'.format(y,x))
            adm01shp1 = adm01shp1.merge(adm01shp2, on = 'geometry')
            adm01shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/adm01.shp'.format(y,x))
            #for admininstrative level 2 
            adm02shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/NTL_stats_adm02_mean.shp'.format(y,x))
            adm02shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/NTL_stats_adm02_median.shp'.format(y,x))
            adm02shp1 = adm02shp1.merge(adm02shp2, on = 'geometry')
            adm02shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/adm02.shp'.format(y,x))
            # for administrative level 3 
            adm03shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/CH_VNM_adm03.shp'.format(y,x))
            csv1 = pd.read_csv('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/NTL_stats_adm03_mean.csv'.format(y,x))
            csv2 = pd.read_csv('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/NTL_stats_adm03_median.csv'.format(y,x))
            adm03shp1 = adm03shp1.merge(csv1, on = 'GID_3')
            adm03shp1 = adm03shp1.merge(csv2, on = 'GID_3')
            adm03shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/0{}/adm03.shp'.format(y,x))
        else:
            #for administrative level 1
            adm01shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/NTLstats2012_adm01_mean.shp'.format(y,x))
            adm01shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/NTLstats2012_adm01_median.shp'.format(y,x))
            adm01shp1 = adm01shp1.merge(adm01shp2, on = 'geometry') # merging shapefiles to join attributes mean and median
            adm01shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/adm01.shp'.format(y,x))
            #for admininstrative level 2 
            adm02shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/NTL_stats_adm02_mean.shp'.format(y,x))
            adm02shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/NTL_stats_adm02_median.shp'.format(y,x))
            adm02shp1 = adm02shp1.merge(adm02shp2, on = 'geometry')
            adm02shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/adm02.shp'.format(y,x))
            # for administrative level 3 
            adm03shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/CH_VNM_adm03.shp'.format(y,x))
            csv1 = pd.read_csv('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/NTL_stats_adm03_mean.csv'.format(y,x))
            csv2 = pd.read_csv('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/NTL_stats_adm03_median.csv'.format(y,x))
            adm03shp1 = adm03shp1.merge(csv1, on = 'GID_3')
            adm03shp1 = adm03shp1.merge(csv2, on = 'GID_3')
            adm03shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/{}/{}/adm03.shp'.format(y,x))

# %%
import pandas as pd 
import geopandas as gpd

# %%
# for administrative level 3 
adm03shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/CH_VNM_adm03.shp')
csv1 = pd.read_csv('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTL_stats_adm03_mean.csv')
csv2 = pd.read_csv('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTL_stats_adm03_median.csv')
adm03shp1 = adm03shp1.merge(csv1, on = 'GID_3')
adm03shp1 = adm03shp1.merge(csv2, on = 'GID_3')
#adm03shp1 = gpd.GeoDataFrame(adm03shp1)
adm03shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/adm03.shp')
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(adm03shp1['geometry'])
# Out:
# 0       MULTIPOLYGON (((105.83636 28.93850, 105.83901 ...
# 1       MULTIPOLYGON (((105.67599 29.26929, 105.67599 ...
# 2       POLYGON ((106.13786 23.57216, 106.13608 23.577...
# 3       POLYGON ((106.99158 23.30425, 106.98711 23.304...
# 4       POLYGON ((106.68664 22.88927, 106.68548 22.889...
#                               ...
# 6921    POLYGON ((105.85316 22.15133, 105.85271 22.153...
# 6922    POLYGON ((105.85230 22.12834, 105.85216 22.125...
# 6923    POLYGON ((105.82354 22.13854, 105.82407 22.140...
# 6924    POLYGON ((105.82354 22.13854, 105.82198 22.138...
# 6925    POLYGON ((105.85230 22.12834, 105.85550 22.126...
# Name: geometry, Length: 6926, dtype: geometry

# %%
adm03shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/adm03.shp')

# %%
type(adm03shp1)
# Out:
# pandas.core.frame.DataFrame

# %%
#for administrative level 1
adm01shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTLstats2012_adm01_mean.shp')
adm01shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTLstats2012_adm01_median.shp')
adm01shp1 = adm01shp1.merge(adm01shp2, on = 'geometry')
adm01shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/adm01.shp')

# %%
#for administrative level 1
adm01shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTL_stats2012_adm01_mean.shp')
adm01shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTL_stats2012_adm01_median.shp')
adm01shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/adm01.shp')
#for admininstrative level 2 
import geopandas as gpd
adm02shp1 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTL_stats_adm02_mean.shp')
adm02shp2 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/NTL_stats_adm02_median.shp')
adm02shp1 = adm02shp1.merge(adm02shp2, on = 'geometry')
adm02shp1.to_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/01/adm02.shp')

# %%
year = [2013,2013,2014,2015,2016,2017,2018,2019]
months = [1,2,4,5,6,7,8,9,10,11,12]

# %%
import geopandas as gpd

# %%
for y in year:
    print (y)
    for x in months:
        if x < 10:
            adm03 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/0{}/CH_VNM_adm03.shp'.format(x))
            print (adm03.head(5))
        else:
            adm03 = gpd.read_file('D:/Job/NIght_time_light/VIIRS Nighttime DayNight Band Composites Version 1/2013/{}/CH_VNM_adm03.shp'.format(x))
            print (adm03.head(5))
# Out:
# 2013
#   GID_0 NAME_0    GID_1     NAME_1        NL_NAME_1      GID_2     NAME_2  \
# 0   CHN  China  CHN.3_1  Chongqing            ??|??  CHN.3.1_1  Chongqing
# 1   CHN  China  CHN.3_1  Chongqing            ??|??  CHN.3.1_1  Chongqing
# 2   CHN  China  CHN.7_1    Guangxi  ???????|???????  CHN.7.1_1      Baise
# 3   CHN  China  CHN.7_1    Guangxi  ???????|???????  CHN.7.1_1      Baise
# 4   CHN  China  CHN.7_1    Guangxi  ???????|???????  CHN.7.1_1      Baise
#
#   NL_NAME_2         GID_3     NAME_3 VARNAME_3 NL_NAME_3     TYPE_3  \
# 0     ??|??  CHN.3.1.13_1   Jiangjin      None      None       Xiàn
# 1     ??|??  CHN.3.1.29_1  Yongchuan      None      None       Xiàn
# 2       ???   CHN.7.1.1_1      Baise     Baisè       ???  Xiànjíshì
# 3       ???   CHN.7.1.2_1      Debao     Débao       ???       Xiàn
# 4       ???   CHN.7.1.3_1     Jingxi    Jìngxi       ???       Xiàn
#
#      ENGTYPE_3  CC_3 HASC_3  area_km2      layer  \
# 0       County  None   None       NaN  CHN_adm03
# ...
